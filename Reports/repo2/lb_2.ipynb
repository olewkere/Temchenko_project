# %% [markdown]
# # Лабораторна робота №2
#
# ## №1.
# В першому завдані нічого складого: командою print() виводимо потрібні нам речення.

# %%
print("Programming", "Essential", "in")
print("Python\n")
# Out:
# Programming Essential in
# Python

# %% [markdown]
# ## №2
# В другому нам потрібно вивести стрілочку з знаків. Я вирішив це функцією в якій є список котрий виводиться полнійно циклом:

# %%
def print_arrow():
    arrow= [
        "    *",
        "   * *",
        "  *   *",
        " *     *",
        "***   ***",
        "  *   *",
        "  *   *",
        "  *   *",
        "  *****\n",
    ]
    for line in arrow:
        print(line)
print_arrow()
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *   *
#   *****

# %% [markdown]
# ## №3-4
# Третє завдання аналогічне до 1, а в четвертому все той ж print() разом з \n:

# %%
print("I'm student")
print("\n\"I'm\"\n\"\"learning\"\"\n\"\"\"Python!\"\"\"")
# Out:
# I'm student
#
# "I'm"
# ""learning""
# """Python!"""

# %% [markdown]
# ## №5-6
# Треба перевести числа з восмирічного (500) та шестнадцятирічного (777) системи числень відповідно в десяткову:

# %%
number1 = 0o500
number2 = 0x777
print("\nnumber 1 = ",number1," number 2 = ",number2)
# Out:
# number 1 =  320  number 2 =  1911

# %% [markdown]
# ## Відовіді на контрольні питання:
#
# 1. Експоненціальне піднесення до ступеня (**)
# 2. Множення (*), Ділення (/), Цілочисельне ділення (//), Остача від ділення (%)
# 3. Додавання (+), Віднімання (-)
# 4. Порівняння (<, >, <=, >=, ==, !=)
# 5. Логічне І (and)
# 6. Логічне АБО (or)
# 7. Логічне НЕ (not)
# 8. Обчислення виразу 3 в степені 3 в степені 4:

# %%
result = 3 ** 3 ** 4
print(result)
# Out:
# 443426488243037769948249630619149892803

# %% [markdown]
# Escape-символ "\" використовується для створення спеціальних символів або послідовностей символів. При виводі на екран функцією print(), escape-символи дозволяють вставляти спеціальні символи, такі як новий рядок \n, табуляція \t, лапки тощо.
