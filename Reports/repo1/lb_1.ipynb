# %% [markdown]
# # Лабораторна робота №1

# %% [markdown]
# ## 1. Завантаження Python, PyCharm, Git.

# %% [markdown]
# Заходжу на офіційний сайт заватажння Python і завантжую останню версію. При встановленні вказую необхідні мені налаштуавння. Аналогічно і з іншим програмним забезпеченням. Після встановлення переходжу для налаштування зв'язку.

# %% [markdown]
# ## 2. Створення репозиторія в GitHub, створення проекту в PyCharm та ініціалізація Git.

# %% [markdown]
# Ось маю аккаунт на GitHub та створюю репозиторій:
#
# ![](images/1.png)
#
# Створив проект в PyCharm і написав вивід:
#
# ![](images/2.png)
#
# Зв'язуємо тепер наш порект з репозиторієм. Перейдемо в папку з нашим проектом. Після встановлення Git на ЛКМ дступна функція "Bush here" використовуючи її ініціалізуємо Гіт відповідною командою:
#
# ![](images/3.png)
#
# І маємо таку картину. Далі я комічу файл і пушу його відповідними командами.
#
# ![](images/9.png)
#
# Як бачимо все в нас вийшло. З рештою я створив теку де будуть мої ЛР та звіти по ним. Я додав загальну папку і провів аналогічні дії. Тепер можна відкривати в гіхабі проект з кодом та звіт до ЛР, переміщуючись між відповідними папками.
#
# ![](images/13.png)

# %% [markdown]
# ## 3. Відповіді на контрольні питання
#
# 1. Система контролю версій (СКВ) - це програмне забезпечення, яке використовується для відстеження змін у файловій системі та управління історією версій файлів та проектів. Основна мета СКВ - це забезпечити можливість спільної роботи над проектом, відстежувати історію змін, повертатися до попередніх версій файлів та вирішувати конфлікти під час злиття змін від різних розробників. Принципова відмінність між SVN (Subversion) та Git:
#
#     - SVN - централізована СКВ, де історія версій зберігається на сервері, а розробники отримують доступ до неї через сервер. Команди для роботи зі змінами виконуються на сервері.
#
#     - Git - розподілена СКВ, де кожен розробник має локальний репозиторій з повною історією. Розробники можуть працювати офлайн та комітувати зміни локально, а потім синхронізувати їх з віддаленим репозиторієм. Гіт більше сприяє гнучкій роботі та гілкуванню.
#
# 2. Команда git add . додає всі зміни у вашому робочому каталозі до індексу. Індекс - це проміжна область, де ви вказуєте Git, які файли потрібно включити до наступного коміту. Ця команда додає всі нові файли та зміни у вже відстежуваних файлах до індексу. Файли, які додані до індексу, будуть включені до наступного коміту після виконання команди git commit.
#
# 3. Команда git commit створює коміт - фіксовану версію вашого проекту, яка включає в себе всі зміни, які ви додали до індексу за допомогою git add. Коміт містить повідомлення про коміт, яке зазвичай коротко описує, які зміни внесені у цьому коміті. Кожен коміт зберігається у історії репозиторію та має унікальний ідентифікатор.
#
# 4. Розміщення локальної копії Git-репозиторію проєкта на віддаленому, що знаходиться на GitHub, виконується за допомогою команди git push.
